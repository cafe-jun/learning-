# %% [markdown]
# *code를 작성할때 우선 어떤것을 개발할지 개발 명세를 정하는 것이 중요하다.
# *어떤 기능을 추가하고 어떤 함수를 쓰고 어떠한 알고리즘을 적용할것인지에 대해서
# *개발 명세를 정한다
#
# 성적처리 코드 작성
# class_quiz_UTF.txt 를 참고하여 나와있는 기능 명세대로 기능을 구현

# %% [markdown]
# 성적 처리 프로그램
# - 학생들의 성적 데이터는 score_data.txt 를 사용한다
#
# 기능 1
# - 전체 학생의 과목별 성적 합계 평균 출력
#
# 기능 2
# - 특정 학생을 조회하면 학생의 성적 합계와 평균과 석차가 출력
#
# 기능 3
# - 새로운 학생의 자료를 추가하는 기능
# -> 학생 아이디는 고유해야 함(ID가 고유한지 검사하는 기능 필요)
# -> 추가된 학생은 다음번 프로그램 실행시에도 사용할 수 있어야 한다
#
# 기능 4
# 과목별 성적순으로 출력 하는 기능
# -> 사용자가 국, 영, 수 과목중 하나를 선택하면 해당 성적 순으로 전체 학생을 출력
#
# 기능 5
# 성적 수정
# -> 특정 학생의 특정 과목의 성적을 수정할 수 있는 기능

# %% [markdown]
# #1 data import
# #2 이 데이터가 어떤것을 나타내는지 명확히 알려줘야 보기 편하다
# #3 함수를 정의
# def data_import(DB):
#     with open("score_data.txt",'r') as f: # 자동적으로 close를 해줌
#         for line in f.readlines():# 데이터가 한줄한줄 들어옴
#             raw=line.split("\t")# tab으로 구분되어 있다
#             DB.
#
#
#
#
#     pass
#
# #2 processing
# def total_score():
#     pass
# def query_select():
#     pass
# def add_data():
#     pass
# def sort_score():
#     pass
# def rank_score():
#     pass
# def mod_score():
#     pass
# def export_data():
#     pass
# def print_menu():
#     pass
# def main():
#     print_menu()
#     menu_num=input("enter Menu")
#
#     if menu_num='1':
#         total_score()
#         main()# 재귀 함수  1 main 을 다시보여주기위해 while문으로 감싸거나 재귀함수
#     elif menu_num='2'
#         query_select()
#         main()
#     elif menu_num='3'
#         add_data()
#         main()
#     elif menu_num='4'
#         rank_score()
#         main()
#     elif menu_num='5'
#         mod_score()
#         main()
#     else:
#         print(" ending  Thank you ")
#
#
# data_import()

# %% [markdown]
#  답
#  1. data import
#  2. processing
#  3. data export
#
#  data import
#  [{'stu_id':,'name':,'kor':,'eng','math':}, ...]
# def data_import(DB):
# 	with open('score_data.txt', 'r') as f:
# 		for line in f.readlines():
# 			raw=line.split("\t")
# 			DB.append({'stu_id':raw[0],'name':raw[1],'kor':int(raw[2]),'eng':int(raw[3]),'math':int(raw[4][:-1])})
# 	print("Suceesfully Imported")
# 	return 0
#
# # processing
#
# def total_score():
# 	pass
#
# def query_select():
# 	pass
#
# def add_data():
# 	pass
#
# def rank_score():
# 	pass
#
# def mod_data():
# 	pass
#
# #data export
# def export_data():
# 	pass
#
# #interface
# def print_menu():
# 	print("1. Total Score")
# 	print("2. Search Student Score")
# 	print("3. Add Score")
# 	print("4. Rank Subject Score")
# 	print("5. Mod Score")
# 	print("6. EXIT")
#
# #main
# def main():
# 	print_menu()
# 	menu_num=input("Enter Menu :")
#
# 	if menu_num=='1':
# 		total_score()
# 		main()
# 	elif menu_num=='2':
# 		query_select()
# 		main()
# 	elif menu_num=='3':
# 		add_data()
# 		main()
# 	elif menu_num=='4':
# 		rank_score()
# 		main()
# 	elif menu_num=='5':
# 		mod_data()
# 		main()
# 	elif menu_num=='6':
# 		print("Thank You!")
# 		return 0
# 	else:
# 		print("Please Enter right Number!")
# 		main()
#
# DB=[]
#
# data_import(DB)
# main()
# export_data()

# %%
# 1. data import
# 2. processing
# 3. data export

# data import
# [{'stu_id':,'name':,'kor':,'eng','math':}, ...]
def data_import(DB):
    with open('score_data.txt', 'r') as f:
        for line in f.readlines():
            raw=line.split("\t")
            DB.append({'stu_id':raw[0],'name':raw[1],'kor':int(raw[2]),'eng':int(raw[3]),'math':int(raw[4][:-1])})
    print("Suceesfully Imported")
    return 0

# processing
def total_score():
    pass

def query_select():
    pass

def add_data():
    pass

def rank_score():
    pass

def mod_data():
    pass

#data export
def export_data():
    pass

#interface
def print_menu():
    print("1. Total Score")
    print("2. Search Student Score")
    print("3. Add Score")
    print("4. Rank Subject Score")
    print("5. Mod Score")
    print("6. EXIT")

#main
def main():
    print_menu()
    menu_num=input("Enter Menu :")

    if menu_num=='1':
        total_score()
        main()
    elif menu_num=='2':
        query_select()
        main()
    elif menu_num=='3':
        add_data()
        main()
    elif menu_num=='4':
        rank_score()
        main()
    elif menu_num=='5':
        mod_data()
        main()
    elif menu_num=='6':
        print("Thank You!")
        return 0
    else:
        print("Please Enter right Number!")
        main()

DB=[]

data_import(DB)
main()
export_data()
